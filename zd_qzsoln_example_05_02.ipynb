# %%
#   Uhlig's Exampl05.m  Model 2
#   This is  "Economy 2" from Farmer, R.E.A. 
#   and J.T. Guo, "Real Business Cycles and the 
#   Animal Spirits Hypothesis," Journal of Economic 
#  Theory 63, 42-72 (1994).

#  Exampl05  is set-up correctly compared to
#  Exampl04.  Uhlig introduced an additional
#  state variable  c(t)

###  NOTE NOTE
### Py and MAT results match for Models 1 and 2,
### but not model 3
###  differences in eigenvalues matter in Model 3


import numpy as np


#  These are the parameters for  
#  Farmer-Guo Model 2  

lamb = 0.7
b = 0.63
a = 0.3                
psi =1.0/1.05 
sigma_sigma = 0.70

L_bar = 1.0/3
Z_bar = 1
delta = 0.025
rho = 0.99
eta = 1.0


alpha   = a/lamb
betta   = b/lamb  
R_bar = 1.0/rho
YK_bar = (R_bar + delta - 1)/a
K_bar = (YK_bar / (Z_bar*L_bar**betta) )**(1.0/(alpha-1))
I_bar = delta * K_bar
Y_bar = YK_bar * K_bar
C_bar = Y_bar - delta*K_bar
A_bar = C_bar**(-eta) * b * Y_bar/L_bar # Parameter in utility function
     
        

VARNAMES = ['capital',
                         'consumption',
                         'output',
                         'labor',
                         'interest',
                         'investment',
                         'technology']



AA = np.vstack(([0, -C_bar],
                          [- K_bar, 0],
                          [0, 0],
                          [0, -eta],
                          [0, 0]))

BB = np.vstack(([0, 0],
                          [(1-delta)*K_bar, 0],
                          [alpha, 0],
                          [0, 0],
                          [-a*YK_bar, 0]))

CC = np.vstack(([Y_bar, 0, 0, -I_bar],
                           [0, 0, 0, I_bar],
                           [-1, betta, 0, 0],
                           [1, -1, 0, 0],
                           [a*YK_bar, 0, -R_bar, 0]))

DD = np.vstack(([0],
                           [0],
                           [1],
                           [0],
                           [0]))

FF = [0, -eta]

GG = [0, eta]

HH = [0, 0]

JJ = [0, 0, 1, 0]

KK = [0, 0, 0, 0]

LL = [0]

MM = [0]

NN = [psi]


Sigma = [sigma_sigma**2]

Sigma_EPS = Sigma


# %run uhlig_solver_QZ.ipynb
# Out:
# qzdiv(): Inputs unchanged!
# Done. You have the matrices PP QQ  RR  SS  WW.

# %%
print('PP')
print(PP.shape)
print(PP)
print(' ')
print('RR')
print(RR.shape)
print(RR)
print(' ')
print('QQ')
print(QQ.shape)
print(QQ)
print(' ')
print('SS')
print(SS.shape)
print(SS)
print(' ')
print('Delta_up = ', Delta_up)
print(' ')
print('Xi_up = ', Xi_up)
print(' ')
print('UUU = ', UUU)
print(' ')
print('VVV = ', VVV)
# Out:
# PP
# (2, 2)
# [[ 0.932 -0.   ]
#  [ 0.475 -0.   ]]
#
# RR
# (4, 2)
# [[ 0.01  -0.   ]
#  [-0.465 -0.   ]
#  [-0.034 -0.   ]
#  [-1.701 -0.   ]]
#
# QQ
# (2, 1)
# [[0.259]
#  [0.796]]
#
# SS
# (4, 1)
# [[ 2.837]
#  [ 2.041]
#  [ 0.099]
#  [10.347]]
#
# Delta_up =  [[ 1.000e+00+0.000e+00j  0.000e+00+0.000e+00j  0.000e+00+0.000e+00j
#    0.000e+00+0.000e+00j]
#  [ 0.000e+00+0.000e+00j -7.034e-01-7.674e-17j -4.067e-01+5.842e-01j
#    3.489e-03+6.563e-03j]
#  [ 0.000e+00+0.000e+00j  1.676e-17+1.872e-17j -2.464e-17+3.020e-18j
#   -1.100e-01+2.144e-01j]
#  [ 0.000e+00+0.000e+00j  0.000e+00+0.000e+00j  0.000e+00+0.000e+00j
#    9.907e-01-1.527e-16j]]
#
# Xi_up =  [[ 0.000e+00+0.000e+00j  1.526e-01-2.905e-01j  3.513e-02+6.767e-02j
#   -9.415e-01+4.598e-03j]
#  [ 0.000e+00+0.000e+00j -6.559e-01+5.470e-17j  3.829e-01-5.499e-01j
#   -3.916e-02-7.365e-02j]
#  [ 0.000e+00+0.000e+00j  5.551e-17+5.551e-17j -1.188e+00+1.233e-32j
#    1.838e-01-3.583e-01j]
#  [ 0.000e+00+0.000e+00j  0.000e+00+0.000e+00j  0.000e+00+0.000e+00j
#    1.195e+00+0.000e+00j]]
#
# UUU =  [[ 0.   +0.j     0.   +0.j     0.   +0.j     1.   +0.j   ]
#  [ 0.703-0.365j  0.103-0.174j  0.373+0.439j  0.   +0.j   ]
#  [ 0.339-0.449j  0.217-0.036j -0.693-0.393j  0.   +0.j   ]
#  [-0.236+0.001j  0.954-0.005j  0.182-0.001j  0.   +0.j   ]]
#
# VVV =  [[ 0.   +0.j     0.3  -0.57j   0.328+0.631j  0.282-0.001j]
#  [ 0.   +0.j     0.153-0.291j  0.035+0.068j -0.942+0.005j]
#  [ 0.   +0.j     0.321-0.612j -0.322-0.62j   0.184-0.001j]
#  [ 1.   +0.j     0.   +0.j     0.   +0.j     0.   +0.j   ]]
