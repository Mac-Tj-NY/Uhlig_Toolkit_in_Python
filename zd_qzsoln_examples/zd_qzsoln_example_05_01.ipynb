# %%
#   Uhlig's Exampl05.m  Model 1
#   This is  "Economy 1" from Farmer, R.E.A. 
#   and J.T. Guo, "Real Business Cycles and the 
#   Animal Spirits Hypothesis," Journal of Economic 
#  Theory 63, 42-72 (1994).

#  Exampl05  is set-up correctly compared to
#  Exampl04.  Uhlig introduced an additional
#  state variable  c(t)

###  NOTE NOTE
### Py and MAT results match for Model 1,
### but not model 3
###  differences in eigenvalues matter in Model 3


import numpy as np


#  These are the parameters for  
#  Farmer-Guo Model 1  

lamb = 1
b = 0.64
a = 0.36                
psi =1.0/1.05 
sigma_sigma = 0.70

L_bar = 1.0/3
Z_bar = 1
delta = 0.025
rho = 0.99
eta = 1.0


alpha   = a/lamb
betta   = b/lamb  
R_bar = 1.0/rho
YK_bar = (R_bar + delta - 1)/a
K_bar = (YK_bar / (Z_bar*L_bar**betta) )**(1.0/(alpha-1))
I_bar = delta * K_bar
Y_bar = YK_bar * K_bar
C_bar = Y_bar - delta*K_bar
A_bar = C_bar**(-eta) * b * Y_bar/L_bar # Parameter in utility function
     
        

VARNAMES = ['capital',
                         'consumption',
                         'output',
                         'labor',
                         'interest',
                         'investment',
                         'technology']



AA = np.vstack(([0, -C_bar],
                          [- K_bar, 0],
                          [0, 0],
                          [0, -eta],
                          [0, 0]))

BB = np.vstack(([0, 0],
                          [(1-delta)*K_bar, 0],
                          [alpha, 0],
                          [0, 0],
                          [-a*YK_bar, 0]))

CC = np.vstack(([Y_bar, 0, 0, -I_bar],
                           [0, 0, 0, I_bar],
                           [-1, betta, 0, 0],
                           [1, -1, 0, 0],
                           [a*YK_bar, 0, -R_bar, 0]))

DD = np.vstack(([0],
                           [0],
                           [1],
                           [0],
                           [0]))

FF = [0, -eta]

GG = [0, eta]

HH = [0, 0]

JJ = [0, 0, 1, 0]

KK = [0, 0, 0, 0]

LL = [0]

MM = [0]

NN = [psi]


Sigma = [sigma_sigma**2]

Sigma_EPS = Sigma


# %run uhlig_solver_QZ.ipynb
# Out:
# qzdiv(): Inputs unchanged!
# Done. You have the matrices PP QQ  RR  SS  WW.

# %%
print('PP')
print(PP.shape)
print(PP)
print(' ')
print('RR')
print(RR.shape)
print(RR)
print(' ')
print('QQ')
print(QQ.shape)
print(QQ)
print(' ')
print('SS')
print(SS.shape)
print(SS)
print(' ')
print('Delta_up = ', Delta_up)
print(' ')
print('Xi_up = ', Xi_up)
print(' ')
print('UUU = ', UUU)
print(' ')
print('VVV = ', VVV)
# Out:
# PP
# (2, 2)
# [[ 0.942 -0.   ]
#  [ 0.532  0.   ]]
#
# RR
# (4, 2)
# [[ 0.055 -0.   ]
#  [-0.477 -0.   ]
#  [-0.033 -0.   ]
#  [-1.327 -0.   ]]
#
# QQ
# (2, 1)
# [[0.153]
#  [0.478]]
#
# SS
# (4, 1)
# [[1.928]
#  [1.451]
#  [0.067]
#  [6.135]]
#
# Delta_up =  [[ 1.000e+00+0.j  0.000e+00+0.j  0.000e+00+0.j  0.000e+00-0.j]
#  [ 0.000e+00+0.j  6.956e-01+0.j -8.889e-02+0.j  7.152e-01+0.j]
#  [ 0.000e+00+0.j  0.000e+00+0.j  1.027e+00+0.j  1.072e-01+0.j]
#  [ 0.000e+00+0.j  0.000e+00+0.j  0.000e+00+0.j -6.160e-17-0.j]]
#
# Xi_up =  [[ 0.   +0.j  0.361+0.j -0.918+0.j -0.165-0.j]
#  [ 0.   +0.j  0.655+0.j  0.136+0.j -0.642-0.j]
#  [ 0.   +0.j  0.   +0.j  1.101+0.j -0.209-0.j]
#  [ 0.   +0.j  0.   +0.j  0.   +0.j  4.368+0.j]]
#
# UUU =  [[ 0.000e+00+0.j  0.000e+00+0.j  0.000e+00+0.j  1.000e+00+0.j]
#  [-9.928e-17+0.j -2.180e-01+0.j  9.760e-01+0.j  0.000e+00+0.j]
#  [-9.809e-17+0.j  9.760e-01+0.j  2.180e-01+0.j  0.000e+00+0.j]
#  [-1.000e+00+0.j  3.346e-17+0.j -8.493e-17+0.j  0.000e+00+0.j]]
#
# VVV =  [[ 0.   +0.j  0.639+0.j  0.373+0.j -0.673-0.j]
#  [ 0.   +0.j  0.361+0.j -0.918+0.j -0.165-0.j]
#  [ 0.   +0.j  0.679+0.j  0.137+0.j  0.721+0.j]
#  [ 1.   +0.j  0.   +0.j  0.   +0.j  0.   -0.j]]
